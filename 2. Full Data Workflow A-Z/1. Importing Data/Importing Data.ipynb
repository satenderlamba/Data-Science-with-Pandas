# %% [markdown]
# ## Importing CSV files

# %%
with open('titanic.csv') as f:   # reading from a .csv
    text = f.readlines()

# %% [markdown]
# text is too long, no point in seeing it here and let it take 1000 lines of space in Github

# %%
len(text)
# Out:
# 892

# %% [markdown]
# The pandas method:

# %%
import pandas as pd

# %%
pd.read_csv('titanic.csv')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %% [markdown]
# index_col parameter

# %%
pd.read_csv('titanic.csv', index_col = 'pclass')
# Out:
#         survived     sex   age  sibsp  parch     fare embarked deck
# pclass
# 3              0    male  22.0      1      0   7.2500        S  NaN
# 1              1  female  38.0      1      0  71.2833        C    C
# 3              1  female  26.0      0      0   7.9250        S  NaN
# 1              1  female  35.0      1      0  53.1000        S    C
# 3              0    male  35.0      0      0   8.0500        S  NaN
# ...          ...     ...   ...    ...    ...      ...      ...  ...
# 2              0    male  27.0      0      0  13.0000        S  NaN
# 1              1  female  19.0      0      0  30.0000        S    B
# 3              0  female   NaN      1      2  23.4500        S  NaN
# 1              1    male  26.0      0      0  30.0000        C    C
# 3              0    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 8 columns]

# %% [markdown]
# header parameter

# %%
pd.read_csv('titanic.csv', header = 0)  # define which row should serve as headero of the dataframe, it can be none as well
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %% [markdown]
# names parameter to change the column labels

# %%
pd.read_csv('titanic.csv', header = 0, names = ['alive', 'class', 'gender', 'age', 'sibsp', 'parch', 'price', 'emb', 'deck'])
# Out:
#      alive  class  gender   age  sibsp  parch    price emb deck
# 0        0      3    male  22.0      1      0   7.2500   S  NaN
# 1        1      1  female  38.0      1      0  71.2833   C    C
# 2        1      3  female  26.0      0      0   7.9250   S  NaN
# 3        1      1  female  35.0      1      0  53.1000   S    C
# 4        0      3    male  35.0      0      0   8.0500   S  NaN
# ..     ...    ...     ...   ...    ...    ...      ...  ..  ...
# 886      0      2    male  27.0      0      0  13.0000   S  NaN
# 887      1      1  female  19.0      0      0  30.0000   S    B
# 888      0      3  female   NaN      1      2  23.4500   S  NaN
# 889      1      1    male  26.0      0      0  30.0000   C    C
# 890      0      3    male  32.0      0      0   7.7500   Q  NaN
#
# [891 rows x 9 columns]

# %% [markdown]
# usecols parameter to tell only which columns to import

# %%
titanic = pd.read_csv('titanic.csv', header = 0, index_col= 'pclass', usecols = ['survived', 'pclass', 'sex', 'age'])

# %%
titanic.head()
# Out:
#         survived     sex   age
# pclass
# 3              0    male  22.0
# 1              1  female  38.0
# 3              1  female  26.0
# 1              1  female  35.0
# 3              0    male  35.0

# %% [markdown]
# changing column labels

# %%
titanic.columns = ['alive', 'gender', 'age']

# %%
titanic.index.name = 'class'

# %%
titanic.head()
# Out:
#        alive  gender   age
# class
# 3          0    male  22.0
# 1          1  female  38.0
# 3          1  female  26.0
# 1          1  female  35.0
# 3          0    male  35.0

# %% [markdown]
# ## Importing messy CSV files

# %%
import pandas as pd

# %%
pd.read_csv('titanic_raw.csv')  # messy data
# Out:
#                                               This       is       the  \
# It   contains  all       passengers  that     were   aboard       the
# the  tragic    disaster  occured     in        the     year        19
# 0   0         3         male        22.0         1        0     $7.25
# 1   1         1         female      38.0         1        0  $71.2833
# 2   1         3         female      26.0         0        0    $7.925
# ...                                            ...      ...       ...
# 891 0         2         male        24.0         0        0     $10.5
# 892 0         3         male        34.0         1        1     $14.4
# 893 0         3         male        36.0         0        0   $7.8958
# End  of        the       Dataset                                  NaN
# Get  more      Datasets  on          Kaggle      .      com       NaN
#
#                                               Titanic  Dataset.
# It   contains  all       passengers  that     titanic      when
# the  tragic    disaster  occured     in             1         2
# 0   0         3         male        22.0            S       NaN
# 1   1         1         female      38.0            C         C
# 2   1         3         female      26.0            S       NaN
# ...                                               ...       ...
# 891 0         2         male        24.0            S       NaN
# 892 0         3         male        34.0            S       NaN
# 893 0         3         male        36.0            S       NaN
# End  of        the       Dataset                  NaN       NaN
# Get  more      Datasets  on          Kaggle       NaN       NaN
#
# [898 rows x 5 columns]

# %%
col_names = ['Survived', 'Class', 'Gender', 'Age', 'Sibsp', 'Parch', 'Fare', 'Emb', 'Deck']

# %%
titanic = pd.read_csv('titanic_raw.csv', skiprows = 3, skipfooter = 2, header =  None, names = col_names)
# Out:
# E:\Anaconda\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)

# %%
titanic.head()
# Out:
#   Survived  Class  Gender   Age  Sibsp  Parch      Fare Emb Deck
# 0        0      3    male  22.0      1      0     $7.25   S  NaN
# 1        1      1  female  38.0      1      0  $71.2833   C    C
# 2        1      3  female  26.0      0      0    $7.925   S  NaN
# 3        1      1  female  35.0      1      0     $53.1   S    C
# 4        0      3    male  35.0      0      0     $8.05   S  NaN

# %%
titanic.to_csv('titanic_clean.csv', index = False)  # saving the clean csv to disk

# %%
pd.read_csv('titanic_clean.csv')  # another range index is saved here if index = True during saving
# Out:
#     Survived  Class  Gender   Age  Sibsp  Parch      Fare Emb Deck
# 0          0      3    male  22.0      1      0     $7.25   S  NaN
# 1          1      1  female  38.0      1      0  $71.2833   C    C
# 2          1      3  female  26.0      0      0    $7.925   S  NaN
# 3          1      1  female  35.0      1      0     $53.1   S    C
# 4          0      3    male  35.0      0      0     $8.05   S  NaN
# ..       ...    ...     ...   ...    ...    ...       ...  ..  ...
# 889        1      1    male  26.0      0      0     $30.0   C    C
# 890        0      3    male  32.0      0      0     $7.75   Q  NaN
# 891        0      2    male  24.0      0      0     $10.5   S  NaN
# 892        0      3    male  34.0      1      1     $14.4   S  NaN
# 893        0      3    male  36.0      0      0   $7.8958   S  NaN
#
# [894 rows x 9 columns]

# %% [markdown]
# ## Importing from Excel Files with pd.read_excel( )

# %% [markdown]
# ### First steps

# %%
import pandas as pd

# %%
sales = pd.read_excel('sales.xls')   # importing excel and converting it to dataframe

# %% [markdown]
# by default, first column is the index of the dataframe, i.e the sales column, but also a rangeIndex

# %%
sales
# Out:
#   Unnamed: 0      City Country  Sales  Bonus
# 0       Mike  New York     USA     25    2.5
# 1        Jim    Boston     USA     43    4.3
# 2     Steven    London      UK     76    7.6
# 3        Joe    Madrid   Spain     12    1.8
# 4        Tom     Paris  France     89   13.4

# %% [markdown]
# let's change that!

# %%
sales = pd.read_excel('sales.xls', index_col = 0 )  # seting sales as index

# %%
sales
# Out:
#             City Country  Sales  Bonus
# Mike    New York     USA     25    2.5
# Jim       Boston     USA     43    4.3
# Steven    London      UK     76    7.6
# Joe       Madrid   Spain     12    1.8
# Tom        Paris  France     89   13.4

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, Mike to Tom
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   City     5 non-null      object
#  1   Country  5 non-null      object
#  2   Sales    5 non-null      int64
#  3   Bonus    5 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 200.0+ bytes

# %%
pd.read_excel('sales.xls', index_col = 0, header = 0)        # header can also be 'None'
# Out:
#             City Country  Sales  Bonus
# Mike    New York     USA     25    2.5
# Jim       Boston     USA     43    4.3
# Steven    London      UK     76    7.6
# Joe       Madrid   Spain     12    1.8
# Tom        Paris  France     89   13.4

# %% [markdown]
# changing column labels

# %%
pd.read_excel('sales.xls', index_col = 0, header = 0, names = ['name', 'Loc_city', 'loc_country', 'revenue', 'Add_comp'])
# Out:
#         Loc_city loc_country  revenue  Add_comp
# name
# Mike    New York         USA       25       2.5
# Jim       Boston         USA       43       4.3
# Steven    London          UK       76       7.6
# Joe       Madrid       Spain       12       1.8
# Tom        Paris      France       89      13.4

# %% [markdown]
# specify which columns to use

# %%
pd.read_excel('sales.xls', index_col = 0, header = 0, usecols = "A:C")    # columns have Alphabetical labels in excel, both including
# Out:
#             City Country
# Mike    New York     USA
# Jim       Boston     USA
# Steven    London      UK
# Joe       Madrid   Spain
# Tom        Paris  France

# %%
pd.read_excel('sales.xls', index_col = 0, header = 0, usecols = 'A, C:E')
# Out:
#        Country  Sales  Bonus
# Mike       USA     25    2.5
# Jim        USA     43    4.3
# Steven      UK     76    7.6
# Joe      Spain     12    1.8
# Tom     France     89   13.4

# %%
pd.read_excel('sales.xls', index_col = 0, header = 0, usecols = 'C:')  # doesn't work
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12828/3623767868.py in <module>
# ----> 1 pd.read_excel('sales.xls', index_col = 0, header = 0, usecols = 'C:')  # doesn't work
#
# E:\Anaconda\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# E:\Anaconda\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     370
#     371     try:
# --> 372         data = io.parse(
#     373             sheet_name=sheet_name,
#     374             header=header,
#
# E:\Anaconda\anaconda3\lib\site-packages\pandas\io\excel\_base.py in parse(self, sheet_name, header, names, index_col, usecols, squeeze, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#    1270             DataFrame from the passed in Excel file.
#    1271         """
# -> 1272         return self._reader.parse(
#    1273             sheet_name=sheet_name,
#    1274             header=header,
#
# E:\Anaconda\anaconda3\lib\site-packages\pandas\io\excel\_base.py in parse(self, sheet_name, header, names, index_col, usecols, squeeze, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     625                 )
#     626
# --> 627                 output[asheetname] = parser.read(nrows=nrows)
#     628
#     629                 if not squeeze or isinstance(output[asheetname], DataFrame):
#
# E:\Anaconda\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read(self, nrows)
#    1045     def read(self, nrows=None):
#    1046         nrows = validate_integer("nrows", nrows)
# -> 1047         index, columns, col_dict = self._engine.read(nrows)
#    1048
#    1049         if index is None:
#
# E:\Anaconda\anaconda3\lib\site-packages\pandas\io\parsers\python_parser.py in read(self, rows)
#     282
#     283         data = self._convert_data(data)
# --> 284         index, columns = self._make_index(data, alldata, columns, indexnamerow)
#     285
#     286         return index, columns, data
#
# E:\Anaconda\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py in _make_index(self, data, alldata, columns, indexnamerow)
#     413
#     414         elif not self._has_complex_date_col:
# --> 415             index = self._get_simple_index(alldata, columns)
#     416             index = self._agg_index(index)
#     417         elif self._has_complex_date_col:
#
# E:\Anaconda\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py in _get_simple_index(self, data, columns)
#     454             data.pop(i)
#     455             if not self._implicit_index:
# --> 456                 columns.pop(i)
#     457
#     458         return index
#
# IndexError: pop from empty list

# %%
pd.read_excel('sales.xls', index_col = 0, header = 0, usecols = [0,3,4])
# Out:
#         Sales  Bonus
# Mike       25    2.5
# Jim        43    4.3
# Steven     76    7.6
# Joe        12    1.8
# Tom        89   13.4

# %%
pd.read_excel('sales.xls', index_col = 0, header = 0, usecols = ['City', 'Sales'])   # not recommended tho, use excel labels
# Out:
#           Sales
# City
# New York     25
# Boston       43
# London       76
# Madrid       12
# Paris        89
