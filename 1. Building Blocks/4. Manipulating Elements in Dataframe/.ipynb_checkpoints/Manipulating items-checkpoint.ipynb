# %% [markdown]
# # Manipulating values in dataframe

# %% [markdown]
# ### Best practice

# %%
import pandas as pd

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %% [markdown]
# #### changing a single value ( Option 1 with loc)

# %%
titanic.loc[1, 'age'] = 40  # change age of row 1 to 40

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  40.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %% [markdown]
# #### Changing a single value ( option 2 with iloc )

# %%
titanic.iloc[1, 3] = 41    # row = 1 column = 3

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  41.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %% [markdown]
# ####  Changing multiple values ( option 1: loc)

# %%
titanic.loc[1:3, 'age'] = 42  # REMEMBER!!! both ends are including in loc

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  42.0      1      0  71.2833        C    C
# 2         1       3  female  42.0      0      0   7.9250        S  NaN
# 3         1       1  female  42.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %% [markdown]
# #### Changing multiple vales ( option 2: iloc )

# %%
titanic.iloc[1:4, 3] = [54, 56, 78]

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  54.0      1      0  71.2833        C    C
# 2         1       3  female  56.0      0      0   7.9250        S  NaN
# 3         1       1  female  78.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %% [markdown]
# #### Changing multiple values in column ( option 3: boolean indexing)

# %%
index_babies = titanic.loc[titanic.age < 1, 'age'].index  # saving index objects onject of all babies

# %%
titanic.loc[titanic.age < 1, 'age'] = 1  # rounding all baby ages to 1

# %%
titanic.loc[index_babies]
# Out:
#      survived  pclass     sex  age  sibsp  parch      fare embarked deck
# 78          1       2    male  1.0      0      2   29.0000        S  NaN
# 305         1       1    male  1.0      1      2  151.5500        S    C
# 469         1       3  female  1.0      2      1   19.2583        C  NaN
# 644         1       3  female  1.0      2      1   19.2583        C  NaN
# 755         1       2    male  1.0      1      1   14.5000        S  NaN
# 803         1       3    male  1.0      0      1    8.5167        C  NaN
# 831         1       2    male  1.0      1      1   18.7500        S  NaN

# %% [markdown]
# ### Changing multiple values in a row

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  54.0      1      0  71.2833        C    C
# 2         1       3  female  56.0      0      0   7.9250        S  NaN
# 3         1       1  female  78.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.loc[0, 'survived':'sex'] = [1, 1, 'female']

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         1       1  female  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  54.0      1      0  71.2833        C    C
# 2         1       3  female  56.0      0      0   7.9250        S  NaN
# 3         1       1  female  78.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %% [markdown]
# ### Changing multiple values in multiple rows/columns

# %%
titanic.replace(0, 'Zero')  # replace all 0s with string zero, this also has an inplace parameter
# Out:
#     survived  pclass     sex   age sibsp parch     fare embarked deck
# 0          1       1  female  22.0     1  Zero     7.25        S  NaN
# 1          1       1  female  54.0     1  Zero  71.2833        C    C
# 2          1       3  female  56.0  Zero  Zero    7.925        S  NaN
# 3          1       1  female  78.0     1  Zero     53.1        S    C
# 4       Zero       3    male  35.0  Zero  Zero     8.05        S  NaN
# ..       ...     ...     ...   ...   ...   ...      ...      ...  ...
# 886     Zero       2    male  27.0  Zero  Zero     13.0        S  NaN
# 887        1       1  female  19.0  Zero  Zero     30.0        S    B
# 888     Zero       3  female   NaN     1     2    23.45        S  NaN
# 889        1       1    male  26.0  Zero  Zero     30.0        C    C
# 890     Zero       3    male  32.0  Zero  Zero     7.75        Q  NaN
#
# [891 rows x 9 columns]

# %% [markdown]
# ## How NOT to do it ( Part 1)

# %%
import pandas as pd

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %% [markdown]
# Example 1:

# %%
age = titanic.age

# %%
age.head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: age, dtype: float64

# %%
age[1] = 40 # actualy works but not recommended
# Out:
# C:\Users\Satender\AppData\Local\Temp/ipykernel_3028/2108408145.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   age[1] = 40

# %%
age.head()
# Out:
# 0    22.0
# 1    40.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: age, dtype: float64

# %%
titanic.head()  # change reflects here as well
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  41.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.age[1] = 41  # Chained indexing
# Out:
# C:\Users\Satender\AppData\Local\Temp/ipykernel_3028/3910025556.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic.age[1] = 41  # Chained indexing

# %%
titanic.loc[1, 'age'] = 42 # This isn't chained indexing and best way.

# %% [markdown]
# Chained indexing is bad, warning is bad!

# %% [markdown]
# Example 2:

# %%
slice1 = titanic[['sex', 'age']]
slice1.head()
# Out:
#       sex   age
# 0    male  22.0
# 1  female  42.0
# 2  female  26.0
# 3  female  35.0
# 4    male  35.0

# %%
slice1.iloc[1,1] = 43  # still chained indexing
# Out:
# E:\Anaconda\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
slice1  # worked
# Out:
#         sex   age
# 0      male  22.0
# 1    female  43.0
# 2    female  26.0
# 3    female  35.0
# 4      male  35.0
# ..      ...   ...
# 886    male  27.0
# 887  female  19.0
# 888  female   NaN
# 889    male  26.0
# 890    male  32.0
#
# [891 rows x 2 columns]

# %%
titanic.head()  # original dataframe isn't changed
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  42.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %% [markdown]
# Example 3:

# %%
slice2 = titanic.loc[:, ['sex', 'age']]

# %%
slice2
# Out:
#         sex   age
# 0      male  22.0
# 1    female  42.0
# 2    female  26.0
# 3    female  35.0
# 4      male  35.0
# ..      ...   ...
# 886    male  27.0
# 887  female  19.0
# 888  female   NaN
# 889    male  26.0
# 890    male  32.0
#
# [891 rows x 2 columns]

# %%
slice2.iloc[1,1] = 44

# %%
slice2.head()
# Out:
#       sex   age
# 0    male  22.0
# 1  female  44.0
# 2  female  26.0
# 3  female  35.0
# 4    male  35.0

# %%
titanic.head()  # no change
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  42.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %% [markdown]
# Example 4: boolean indexing first, then slicing for 'age'

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
index_babies = titanic[titanic.age < 1].index

# %%
titanic.loc[titanic.age < 1]['age'] = 1
# Out:
# C:\Users\Satender\AppData\Local\Temp/ipykernel_3028/4242492585.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic.loc[titanic.age < 1]['age'] = 1

# %%
titanic.loc[index_babies]  #did not change the values, mission failed
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck
# 78          1       2    male  0.83      0      2   29.0000        S  NaN
# 305         1       1    male  0.92      1      2  151.5500        S    C
# 469         1       3  female  0.75      2      1   19.2583        C  NaN
# 644         1       3  female  0.75      2      1   19.2583        C  NaN
# 755         1       2    male  0.67      1      1   14.5000        S  NaN
# 803         1       3    male  0.42      0      1    8.5167        C  NaN
# 831         1       2    male  0.83      1      1   18.7500        S  NaN

# %% [markdown]
# Example 5: slicing for 'age' first then boolean indexing, opposite order of example 4

# %%
titanic['age'][titanic.age < 1] = 1
# Out:
# C:\Users\Satender\AppData\Local\Temp/ipykernel_3028/2433101966.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic['age'][titanic.age < 1] = 1

# %%
titanic.loc[index_babies]  #worked this time, very confusing
# Out:
#      survived  pclass     sex  age  sibsp  parch      fare embarked deck
# 78          1       2    male  1.0      0      2   29.0000        S  NaN
# 305         1       1    male  1.0      1      2  151.5500        S    C
# 469         1       3  female  1.0      2      1   19.2583        C  NaN
# 644         1       3  female  1.0      2      1   19.2583        C  NaN
# 755         1       2    male  1.0      1      1   14.5000        S  NaN
# 803         1       3    male  1.0      0      1    8.5167        C  NaN
# 831         1       2    male  1.0      1      1   18.7500        S  NaN

# %% [markdown]
# Example 6:

# %%
titanic[['sex', 'age']][titanic.age == 1]['age'] = 0     #no warnings this time!!

# %%
titanic.loc[index_babies]   # didn't change in original data
# Out:
#      survived  pclass     sex  age  sibsp  parch      fare embarked deck
# 78          1       2    male  1.0      0      2   29.0000        S  NaN
# 305         1       1    male  1.0      1      2  151.5500        S    C
# 469         1       3  female  1.0      2      1   19.2583        C  NaN
# 644         1       3  female  1.0      2      1   19.2583        C  NaN
# 755         1       2    male  1.0      1      1   14.5000        S  NaN
# 803         1       3    male  1.0      0      1    8.5167        C  NaN
# 831         1       2    male  1.0      1      1   18.7500        S  NaN
